# %%
import pandas as pd

df = pd.read_csv('data_sf.csv')

print(df.head())
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...

# %%
import pandas as pd

football = pd.read_csv('data_sf.csv')
display(football.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12897 entries, 0 to 12896
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12897 non-null  int64
#  1   Name             12897 non-null  object
#  2   Age              12897 non-null  int64
#  3   Nationality      12897 non-null  object
#  4   Club             12897 non-null  object
#  5   Value            12897 non-null  int64
#  6   Wage             12897 non-null  int64
#  7   Position         12897 non-null  object
#  8   Crossing         12897 non-null  int64
#  9   Finishing        12897 non-null  int64
#  10  HeadingAccuracy  12897 non-null  int64
#  11  ShortPassing     12897 non-null  int64
#  12  Volleys          12897 non-null  int64
#  13  Dribbling        12897 non-null  int64
#  14  Curve            12897 non-null  int64
#  15  FKAccuracy       12897 non-null  int64
#  16  LongPassing      12897 non-null  int64
# ...

# %%
import pandas as pd

football = pd.read_csv('data_sf.csv')
football.describe()
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
football.describe(include = ['object'])
# Out:
#                 Name Nationality              Club Position
# count          12897       12897             12897    12897
# unique         12326         156               650       27
# top     J. Rodríguez     England  V-Varen Nagasaki       GK
# freq               9        1368                30     1641

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(football.describe())
# Out:
#          Unnamed: 0           Age         Value           Wage      Crossing  \
# count  12897.000000  12897.000000  1.289700e+04   12897.000000  12897.000000
# mean    6605.040862     24.795379  2.112449e+06    7517.562224     47.076374
# std     3782.545526      4.872212  6.498424e+06   23061.985387     18.043470
# min        0.000000     16.000000  0.000000e+00    1000.000000      5.000000
# 25%     3357.000000     21.000000  2.500000e+05    1000.000000     35.000000
# 50%     6622.000000     24.000000  5.000000e+05    2000.000000     51.000000
# 75%     9876.000000     28.000000  8.500000e+05    4000.000000     61.000000
# max    13125.000000     45.000000  1.185000e+08  565000.000000     93.000000
#
#           Finishing  HeadingAccuracy  ShortPassing       Volleys  \
# count  12897.000000     12897.000000  12897.000000  12897.000000
# mean      42.876328        50.202528     56.026983     40.295030
# std       19.096935        17.281593     14.740436     17.080687
# ...

# %%
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
df.mean()
# Out:
# foo    4.5
# bar    5.7
# baz    6.5
# dtype: float64

# %%
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
df['foo']
df.bar
# Out:
# 0     1.2
# 1     2.2
# 2     3.2
# 3     4.2
# 4     5.2
# 5     6.2
# 6     7.2
# 7     8.2
# 8     9.2
# 9    10.2
# Name: bar, dtype: float64

# %%
df = pd.DataFrame([[i,i+1.2,i+2, 'hi'] for i in range(10)],
                  columns = ['foo', 'bar', 'baz', 'foobar'])
df.bar.mean()
# Out:
# 5.7

# %%
import pandas as pd

football = pd.read_csv('data_sf.csv')

df.mean()
# Out:
# foo    4.5
# bar    5.7
# baz    6.5
# dtype: float64

# %%
import pandas as pd
football = pd.read_csv('data_sf.csv')

football[football.Age > 20]
# Out:
#        Unnamed: 0               Name  Age Nationality  \
# 0               0           L. Messi   31   Argentina
# 1               1  Cristiano Ronaldo   33    Portugal
# 2               2          Neymar Jr   26      Brazil
# 3               3             De Gea   27       Spain
# 4               4       K. De Bruyne   27     Belgium
# ...           ...                ...  ...         ...
# 12838       13067          D. Mackay   21    Scotland
# 12857       13086             Wu Lei   21    China PR
# 12861       13090        Y. Uchimura   33       Japan
# 12870       13099           M. Hurst   22    Scotland
# 12873       13102      K. Pilkington   44     England
#
#                              Club      Value    Wage Position  Crossing  \
# 0                    FC Barcelona  110500000  565000       RF        84
# 1                        Juventus   77000000  405000       ST        84
# 2             Paris Saint-Germain  118500000  290000       LW        79
# ...

# %%
#Условия можно и комбинировать, используя операторы & (логическое и) и | (логическое или). 
#Условия при этом заключаются в скобки. Например, если мы хотим получить только тех футболистов, 
#у которых возраст меньше среднего, или игроков 'FC Barcelona':
football[football.Age > football.Age.mean()]
# Out:
#        Unnamed: 0               Name  Age   Nationality  \
# 0               0           L. Messi   31     Argentina
# 1               1  Cristiano Ronaldo   33      Portugal
# 2               2          Neymar Jr   26        Brazil
# 3               3             De Gea   27         Spain
# 4               4       K. De Bruyne   27       Belgium
# ...           ...                ...  ...           ...
# 12746       12975      Teng Shangkun   27      China PR
# 12749       12978         M. Mansour   26  Saudi Arabia
# 12767       12996          Sun Qibin   26      China PR
# 12861       13090        Y. Uchimura   33         Japan
# 12873       13102      K. Pilkington   44       England
#
#                              Club      Value    Wage Position  Crossing  \
# 0                    FC Barcelona  110500000  565000       RF        84
# 1                        Juventus   77000000  405000       ST        84
# 2             Paris Saint-Germain  118500000  290000       LW        79
# ...

# %%
football[(football.Age < football.Age.mean())|
        (football.Club == 'FC Barcelona')]
# Out:
#        Unnamed: 0                Name  Age Nationality               Club  \
# 0               0            L. Messi   31   Argentina       FC Barcelona
# 7               7           L. Suárez   31     Uruguay       FC Barcelona
# 15             15           P. Dybala   24   Argentina           Juventus
# 16             16             H. Kane   24     England  Tottenham Hotspur
# 18             18       M. ter Stegen   26     Germany       FC Barcelona
# ...           ...                 ...  ...         ...                ...
# 12892       13121        J. Lundstram   19     England    Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden     Trelleborgs FF
# 12894       13123           B. Worman   16     England   Cambridge United
# 12895       13124      D. Walker-Rice   17     England    Tranmere Rovers
# 12896       13125           G. Nugent   16     England    Tranmere Rovers
#
#            Value    Wage Position  Crossing  Finishing  ...  Penalties  \
# ...

# %%
#Здесь мы получили среднюю годовую заработную плату футболистов из клуба FC Barcelona,
#возраст которых меньше среднего [возраста футболистов всех клубов]

football[(football.Age < football.Age.mean())&
        (football.Club == 'FC Barcelona')].Wage.mean()
# Out:
# 77454.54545454546

# %%
df = football[football.Wage > football.Wage.mean()]
df.SprintSpeed.mean()
# Out:
# 67.56638061585058

# %%
#Сколько пенальти (Penalties) забили бразильские (Nationality, Brazil) 
#футболисты за период, данные о котором представлены в датасете?
df = football[football.Nationality(Brazil)]
df.SprintSpeed.mean()
# Out:
# 62.41425430560645

# %%
df = football[football.Wage > football.Wage.mean()]

# %%
import pandas as pd
football = pd.read_csv('data_sf.csv')

football[football.Nationality == 'Brazil'].Penalties.sum()
# Out:
# 22789

# %%
#Укажите средний возраст (Age) игроков, у которых точность удара головой (HeadingAccuracy) > 50. 
#Ответ округлите до сотых.
football[(football.HeadingAccuracy >50)].Age.mean()
# Out:
# 25.58771113179944

# %%
#Укажите возраст (Age) самого молодого игрока, у которого хладнокровие (Composure) и реакция (Reactions) 
#превышают 90% от максимального значения, представленного в датасете.
football[(football.Composure > 0.9*football.Composure.max()) &
        (football.Reactions >0.9*football.Reactions.max())].Age.min
# Out:
# <bound method Series.min of 0     31
# 1     33
# 2     26
# 4     27
# 5     27
# 13    32
# 16    24
# 17    27
# 20    29
# 23    30
# 26    26
# 31    26
# 34    29
# Name: Age, dtype: int64>

# %%
#Определите, на сколько средняя реакция (Reactions) самых взрослых игроков 
#(т.е. игроков, чей возраст (Age) равен максимальному) 
#больше средней реакции самых молодых игроков.
#Ответ округлите до сотых.
round(football[(football.Age == football.Age.max())].Reactions.mean()) - (football[(football.Age == football.Age.min())].Reactions.mean())
# Out:
# 22.642857142857146

# %%
round(football[(football.Age == football.Age.max())].Reactions.mean()) - (football[(football.Age == football.Age.min())].Reactions.mean())
# Out:
# 22.642857142857146

# %%
football.Wage == football.Wage.max()
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12892    False
# 12893    False
# 12894    False
# 12895    False
# 12896    False
# Name: Wage, Length: 12897, dtype: bool

# %%
#Из какой страны (Nationality) происходит больше всего игроков, 
#чья стоимость (Value) превышает среднее значение?

df = football[football.Value > football.Value.mean()]
df.Nationality.describe()
# Out:
# count      1747
# unique       98
# top       Spain
# freq        211
# Name: Nationality, dtype: object

# %%
#Определите, во сколько раз средняя зарплата (Wage) голкипера (Position, GK) 
#с максимальным значением показателя " Рефлексы" (GKReflexes) выше средней зарплаты
#голкипера с максимальным значением показателя "Владение мячом" (GKHandling). 
#Ответ округлите до сотых.



GKR = football[(football.Position == 'GK')&(football.GKReflexes == football.GKReflexes.max())].Wage.mean()
GKH = football[(football.Position == 'GK')&(football.GKHandling == football.GKHandling.max())].Wage.mean()
round(GKR/GKH,2)
# Out:
# 2.77

# %%
#Определите, во сколько раз средняя сила удара (ShotPower) самых агрессивных игроков 
#(игроков с максимальным значением показателя "Агрессивность" (Aggression))
#выше средней силы удара игроков с минимальной агрессией. Ответ округлите до сотых.

AGG = football[(football.Aggression == football.Aggression.max())].ShotPower.mean() 
PSF = football[(football.Aggression == football.Aggression.min())].ShotPower.mean()
round(AGG/PSF,2)
# Out:
# 2.08

# %%
small_df = df[df.columns[1:8]].head(25)
small_df
# Out:
#                  Name  Age Nationality                 Club      Value  \
# 0            L. Messi   31   Argentina         FC Barcelona  110500000
# 1   Cristiano Ronaldo   33    Portugal             Juventus   77000000
# 2           Neymar Jr   26      Brazil  Paris Saint-Germain  118500000
# 3              De Gea   27       Spain    Manchester United   72000000
# 4        K. De Bruyne   27     Belgium      Manchester City  102000000
# 5           E. Hazard   27     Belgium              Chelsea   93000000
# 6           L. Modrić   32     Croatia          Real Madrid   67000000
# 7           L. Suárez   31     Uruguay         FC Barcelona   80000000
# 8        Sergio Ramos   32       Spain          Real Madrid   51000000
# 9            J. Oblak   25    Slovenia      Atlético Madrid   68000000
# 10     R. Lewandowski   29      Poland    FC Bayern München   77000000
# 11           T. Kroos   28     Germany          Real Madrid   76500000
# ...

# %%
s = small_df['Nationality'].value_counts()
display(s)
# Out:
# Spain        4
# Belgium      3
# Argentina    3
# Uruguay      3
# Germany      3
# France       2
# England      1
# Brazil       1
# Portugal     1
# Slovenia     1
# Poland       1
# Croatia      1
# Italy        1
# Name: Nationality, dtype: int64

# %%
s.index
# Out:
# Index(['Spain', 'Belgium', 'Argentina', 'Uruguay', 'Germany', 'France',
#        'England', 'Brazil', 'Portugal', 'Slovenia', 'Poland', 'Croatia',
#        'Italy'],
#       dtype='object')

# %%
s['Germany']
# Out:
# 3

# %%
#сборные, в которых больше 1 футболиста
s.loc[s > 1]
# Out:
# Spain        4
# Belgium      3
# Argentina    3
# Uruguay      3
# Germany      3
# France       2
# Name: Nationality, dtype: int64

# %%
s = small_df['Club'].value_counts()
display(s)
len(s.index)
# Out:
# FC Barcelona           4
# Real Madrid            4
# Manchester City        3
# Juventus               3
# Atlético Madrid        3
# FC Bayern München      2
# Paris Saint-Germain    2
# Chelsea                2
# Tottenham Hotspur      1
# Manchester United      1
# Name: Club, dtype: int64
# 10

# %%
import pandas as pd
football = pd.read_csv('data_sf.csv')

# %%
#Отметьте названия футбольных клубов, представленных в датасете наибольшим количеством игроков.

s = football['Club'].value_counts()
len(s.index)
s.loc[s > 5]
# Out:
# V-Varen Nagasaki     30
# Shonan Bellmare      30
# De Graafschap        29
# Padova               29
# FC Emmen             29
#                      ..
# Dijon FCO             8
# Vitória Guimarães     7
# Dinamo Zagreb         7
# GD Chaves             7
# Atlético Mineiro      6
# Name: Club, Length: 650, dtype: int64

# %%
s = football['Club'].value_counts()
s.loc[s == 6]
# Out:
# Atlético Mineiro    6
# Name: Club, dtype: int64

# %%
s = football['Position'].value_counts()
display(s)
len(s.index)
# Out:
# GK     1641
# ST     1512
# CB     1403
# CM     1067
# LB     1002
# RB      948
# RM      766
# LM      728
# CDM     691
# CAM     633
# RCB     418
# LCB     409
# LW      242
# RCM     240
# RW      237
# LCM     233
# LDM     148
# RDM     138
# LS      121
# RS      114
# RWB      70
# LWB      60
# CF       51
# LF        8
# LAM       6
# RF        6
# RAM       5
# Name: Position, dtype: int64
# 27

# %%
#Данные об игроках каких позиций (Position) занимают более 10% датасета?

s = football['Position'].value_counts(normalize=True)
display(s)
# Out:
# GK     0.127239
# ST     0.117237
# CB     0.108785
# CM     0.082732
# LB     0.077692
# RB     0.073505
# RM     0.059394
# LM     0.056447
# CDM    0.053578
# CAM    0.049081
# RCB    0.032411
# LCB    0.031713
# LW     0.018764
# RCM    0.018609
# RW     0.018376
# LCM    0.018066
# LDM    0.011476
# RDM    0.010700
# LS     0.009382
# RS     0.008839
# RWB    0.005428
# LWB    0.004652
# CF     0.003954
# LF     0.000620
# LAM    0.000465
# RF     0.000465
# RAM    0.000388
# Name: Position, dtype: float64

# %%
#Сначала сгруппируем данные по численному признаку без параметра bins:
s = small_df['Age'].value_counts()
display(s)
# Out:
# 27    5
# 32    5
# 31    3
# 26    3
# 29    2
# 24    2
# 33    2
# 30    1
# 28    1
# 25    1
# Name: Age, dtype: int64

# %%
# разобьем весь возможный диапазон зарплат на 4 равных промежутка
s = small_df['Wage'].value_counts(bins=4)
display(s)
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64

# %%
#Теперь видно, что распределение неравномерное и только 2 футболиста из 25 получают сверхвысокую зарплату.

#Давайте посмотрим, что это за футболисты:
small_df.loc[(small_df['Wage'] > s.index[3].left) & (small_df['Wage'] <= s.index[3].right)]
# Out:
#         Name  Age Nationality          Club      Value    Wage Position
# 0   L. Messi   31   Argentina  FC Barcelona  110500000  565000       RF
# 7  L. Suárez   31     Uruguay  FC Barcelona   80000000  455000       RS

# %%
small_df = df[df.columns[0:7]].head(25)

s = small_df['Wage'].value_counts(bins=4)

display(s)

s.index

s.index[3]

s.index[3].left

s.index[3].right

small_df['Wage'] > s.index[3].left
# Out:
# (211750.0, 329500.0]     9
# (93528.999, 211750.0]    8
# (329500.0, 447250.0]     6
# (447250.0, 565000.0]     2
# Name: Wage, dtype: int64
# 0      True
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# Name: Wage, dtype: bool

# %%
s = football['FKAccuracy'].value_counts(bins=5)
display(s)
# Out:
# (21.2, 39.4]     4859
# (39.4, 57.6]     3957
# (57.6, 75.8]     2108
# (2.908, 21.2]    1760
# (75.8, 94.0]      213
# Name: FKAccuracy, dtype: int64

# %%
s = small_df['Nationality'].value_counts()
print(s.index)
print(len(s.index))
# Out:
# Index(['Spain', 'Argentina', 'Germany', 'Uruguay', 'Belgium', 'France',
#        'Croatia', 'Brazil', 'Italy', 'Portugal', 'Poland', 'Slovenia',
#        'England'],
#       dtype='object')
# 13

# %%
#Функция unique возвращает список уникальных элементов из серии.
small_df['Nationality'].unique()
# Out:
# array(['Argentina', 'Portugal', 'Brazil', 'Spain', 'Belgium', 'Croatia',
#        'Uruguay', 'Slovenia', 'Poland', 'Germany', 'France', 'England',
#        'Italy'], dtype=object)

# %%
len(small_df['Nationality'].unique())
# Out:
# 13

# %%
#Но если наша конечная цель - получить количество уникальных значений в серии, 
#то мы можем поступить ещё проще, вызвав функцию nunique

small_df['Nationality'].nunique()
# Out:
# 13

# %%
#Отметьте все варианты кода, после выполнения которого переменная result 
#будет содержать количество видов позиций (Position), 
#которые занимают игроки, представленные в датасете:
df = pd.read_csv('data_sf.csv')

# %%
len(df['Position'].unique())
# Out:
# 27

# %%
df['Position'].unique()
# Out:
# array(['RF', 'ST', 'LW', 'GK', 'RCM', 'LF', 'RS', 'RCB', 'LCM', 'CB',
#        'LDM', 'CAM', 'CDM', 'LS', 'LCB', 'RM', 'LAM', 'LM', 'LB', 'RDM',
#        'RW', 'CM', 'RB', 'RAM', 'CF', 'RWB', 'LWB'], dtype=object)

# %%
df['Position'].count()
# Out:
# 12897

# %%
len(df['Position'].value_counts())
# Out:
# 27

# %%
df['Position'].nunique()
# Out:
# 27

# %%
#Преобразование серии value_counts в датафрейм
#Иногда бывает полезно преобразовать серию,
#получившуюся в результате работы функции value_counts, в датафрейм. 
#Для этого нужно к получившейся серии применить функцию reset_index.

s = small_df['Nationality'].value_counts()
s_df = s.reset_index()

display(s_df)
# Out:
#         index  Nationality
# 0       Spain            4
# 1   Argentina            3
# 2     Germany            3
# 3     Uruguay            3
# 4     Belgium            3
# 5      France            2
# 6     Croatia            1
# 7      Brazil            1
# 8       Italy            1
# 9    Portugal            1
# 10     Poland            1
# 11   Slovenia            1
# 12    England            1

# %%
s_df.columns = ['Nationality','Players Count']

display(s_df)
# Out:
#    Nationality  Players Count
# 0        Spain              4
# 1    Argentina              3
# 2      Germany              3
# 3      Uruguay              3
# 4      Belgium              3
# 5       France              2
# 6      Croatia              1
# 7       Brazil              1
# 8        Italy              1
# 9     Portugal              1
# 10      Poland              1
# 11    Slovenia              1
# 12     England              1

# %%
#У какого процента испанских футболистов (Nationality = 'Spain') зарплата (Wage) 
#находится в пределах 25% минимума от наблюдаемого уровня зарплат среди испанских игроков? 
#Ответ дайте в виде целого числа (округлите полученный результат) без знака %.
sp_wage = football[football.Nationality == 'Spain'].Wage.value_counts(bins=4, sort=False)
display(sp_wage)
round(sp_wage.iloc[0]/sp_wage.sum()*100)
# Out:
# (620.999, 95750.0]      651
# (95750.0, 190500.0]      11
# (190500.0, 285250.0]      6
# (285250.0, 380000.0]      3
# Name: Wage, dtype: int64
# 97

# %%
df = football[football.Nationality == 'Spain']['Wage'].value_counts(bins=4)
len (football[football.Nationality == 'Spain'])
# Out:
# 671

# %%
# Задача 6.2
#Укажите количество национальностей (Nationality),
# к которым относятся футболисты, выступающие за клуб (Club) "Manchester United".
df = football[football.Club == 'Manchester United']['Nationality'].value_counts()
len(df)
# Out:
# 13

# %%
# помощью функции unique определите двух футболистов из Бразилии (Nationality = 'Brazil'), 
#выступающих за клуб (Club) 'Juventus'. 
#Перечислите их имена (Name, как в датафрейме) через запятую в алфавитном порядке.
df = pd.read_csv('data_sf.csv')
df[(df.Nationality == 'Brazil')&(df.Club == 'Juventus')].Name.unique()
# Out:
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
df = football[football.Club == 'Juventus'][football.Nationality == 'Brazil'].value_counts('Name')
display(df)
# Out:
# <ipython-input-146-2349ffe363db>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = football[football.Club == 'Juventus'][football.Nationality == 'Brazil'].value_counts('Name')
# Name
# Douglas Costa    1
# Alex Sandro      1
# dtype: int64

# %%
sp_wage = football[football.Nationality == 'Spain'].Wage.value_counts(bins=4)
display(sp_wage)
round(sp_wage.iloc[0]/sp_wage.sum()*100)
# Out:
# (620.999, 95750.0]      651
# (95750.0, 190500.0]      11
# (190500.0, 285250.0]      6
# (285250.0, 380000.0]      3
# Name: Wage, dtype: int64
# 97

# %%
#Укажите, какой из клубов (Club) насчитывает большее количество футболистов возрастом (Age) старше 35 лет.
df = football[football.Age > 35]['Club'].value_counts()
display(df)
# Out:
# Hokkaido Consadole Sapporo     4
# Club Atlético Huracán          4
# Hammarby IF                    3
# Gimnasia y Esgrima La Plata    3
# Morecambe                      3
#                               ..
# SV Wehen Wiesbaden             1
# KAS Eupen                      1
# IF Elfsborg                    1
# Cosenza                        1
# Exeter City                    1
# Name: Club, Length: 212, dtype: int64

# %%
#Задача 6.5
#С помощью функции value_counts с параметром bins разбейте
#всех футболистов родом из Аргентины (Nationality = 'Argentina') на 4 равные группы по возрасту. 
#Сколько футболистов из Аргентины в возрасте от 34,75 до 41 года?
ARG_age = football[football.Nationality == 'Argentina'].Age.value_counts(bins=4)
display(ARG_age)
ARG_age.iloc[3]
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64
# 49

# %%
# задача 6.6
#Сколько процентов футболистов из Испании (Nationality = 'Spain') имеют возраст (Age) 21 год? 
#Введите с точностью до 2 знаков после запятой без указания знака % (например, 12.35).


sp_all = df[df.Nationality == 'Spain']
sp_21 = df[(df.Nationality == 'Spain') & (df.Age == 21)]
round(len(sp_21)/len(sp_all)*100, 2)
# способ 2
df_sp_21 = df.loc[df.Nationality=="Spain"]["Age"].value_counts(normalize=True).loc[21]
round(df_sp_21*100, 2)
# Out:
# 11.77

# %%
#Функция groupby
#Получился датафрейм, где все параметры, к которым можно было применить соответствующую агрегирующую функцию,
#были просуммированы. Если точнее, были просуммированы все численные параметры. 
#Другие параметры, такие как национальность (Nationality),
#не будут отображены в датафрейме сгруппированных данных. 
#Это связано с тем, что к таким колонкам нельзя применить агрегирующую функцию,
#потому что они содержат не численные параметры, а текст.
#df = pd.read_csv('data_sf.csv')
#df.groupby(['Club']).groups

grouped_df = df.groupby(['Club']).sum()
display(grouped_df)

grouped_df.loc['Ajax']
grouped_df.loc['Ajax']['Wage']
# Out:
#                        Unnamed: 0  Age     Value    Wage  Crossing  Finishing  \
# Club
#  SSV Jahn Regensburg       129124  609  15195000   90000      1104        944
# 1. FC Heidenheim 1846      117834  473  18290000   76000       961        860
# 1. FC Kaiserslautern       167351  544  11195000   33000      1106        918
# 1. FC Köln                  54865  225  46810000   92000       444        357
# 1. FC Magdeburg            116731  515  57525000   84000       948        903
# ...                           ...  ...       ...     ...       ...        ...
# Zagłębie Sosnowiec         220803  656   6815000   27000      1161       1007
# Çaykur Rizespor            119137  557  27515000  118000      1110        921
# Örebro SK                  224465  622   8465000   36000      1114        974
# Östersunds FK              136103  478  11030000   39000       944        805
# Śląsk Wrocław              172358  628   9170000   50000      1058       1054
#
# ...

# %%
#Теперь мы можем получить сумму зарплат игроков этого футбольного клуба:
grouped_df.loc['Ajax']['Wage']
# Out:
# 158000

# %%
grouped_df = df.groupby(['Club'])['Wage'].sum()

display(grouped_df)
# Out:
# Club
#  SSV Jahn Regensburg      90000
# 1. FC Heidenheim 1846     76000
# 1. FC Kaiserslautern      33000
# 1. FC Köln                92000
# 1. FC Magdeburg           84000
#                           ...
# Zagłębie Sosnowiec        27000
# Çaykur Rizespor          118000
# Örebro SK                 36000
# Östersunds FK             39000
# Śląsk Wrocław             50000
# Name: Wage, Length: 650, dtype: int64

# %%
#Но помните наш исходный вопрос: "В каком клубе самая высокая зарплата?"
#Для ответа на этот вопрос нам достаточно лишь отсортировать полученные данные
#по убыванию суммы зарплат с помощью функции sort_values:
grouped_df = df.groupby(['Club'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head(5))
#При использовании функции sort_values мы ввели дополнительный параметр ascending=False,
#который указывает, что данные надо сортировать по убыванию.
# Out:
# Club
# Real Madrid          4138000
# FC Barcelona         3967000
# Manchester City      3097000
# Manchester United    2357000
# Juventus             2335000
# Name: Wage, dtype: int64

# %%
#Отметьте позиции (Position), по которым общая сумма зарплат (Wage) игроков превышает 5 млн евро в год.
grouped_df = df.groupby(['Position'])['Wage'].sum().sort_values(ascending=False)
print(grouped_df.head())
# Out:
# Position
# ST     11873000
# GK      8784000
# CB      7476000
# CM      6194000
# LB      6096000
# CAM     5500000
# LM      5440000
# RM      5098000
# RB      5034000
# CDM     4921000
# Name: Wage, dtype: int64

# %%
#Отметьте позиции (Position), по которым общая сумма зарплат (Wage) игроков превышает 5 млн евро в год.
grouped_df = df.groupby(['Position'])['Wage' ].sum().sort_values(ascending=False)
print((grouped_df > 5000000).head(10))
# Out:
# Position
# ST      True
# GK      True
# CB      True
# CM      True
# LB      True
# CAM     True
# LM      True
# RM      True
# RB      True
# CDM    False
# Name: Wage, dtype: bool

# %%
#Давайте рассмотрим ещё несколько примеров использования функции groupby.

#Например, построим такую таблицу, где сгруппируем игроков по национальностям (Nationality) и посчитаем среднюю зарплату, средний возраст и среднюю силу удара. Ну а что, вдруг это всё как-то взаимосвязано?

#Для подсчета среднего мы будем использовать агрегирующую функцию mean:
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean()
# Out:
#                      Wage        Age  ShotPower
# Nationality
# Afghanistan   1250.000000  22.500000  53.750000
# Albania       5931.034483  23.689655  54.551724
# Algeria      15810.810811  27.027027  56.567568
# Andorra       1000.000000  28.000000  58.000000
# Angola        7100.000000  24.700000  63.700000
# ...                   ...        ...        ...
# Uzbekistan    9000.000000  29.500000  71.500000
# Venezuela     6611.111111  23.638889  57.222222
# Wales         9529.411765  24.754902  48.558824
# Zambia        2833.333333  21.833333  66.833333
# Zimbabwe      5000.000000  26.555556  62.888889
#
# [156 rows x 3 columns]

# %%
#Далее отсортируем по убыванию усредненной зарплаты:
df.groupby(['Nationality'])[['Wage','Age','ShotPower']].mean().sort_values(['Wage'],ascending=False).head(10)
# Out:
#                             Wage        Age  ShotPower
# Nationality
# Dominican Republic  71000.000000  23.000000  75.500000
# Egypt               35545.454545  25.818182  59.363636
# Gabon               28900.000000  26.400000  56.900000
# Croatia             26722.222222  24.819444  54.305556
# Equatorial Guinea   25666.666667  28.000000  55.333333
# Belgium             20024.390244  24.030488  56.390244
# Ecuador             18333.333333  24.619048  60.666667
# Uruguay             17590.361446  26.771084  56.192771
# Brazil              17371.158392  27.898345  58.203310
# Algeria             15810.810811  27.027027  56.567568

# %%
#Что?! Доминиканская республика? Очень странно, давайте поближе посмотрим на данные по этой стране:
df.loc[df['Nationality'] == 'Dominican Republic'][['Name','Club','Wage','Age','ShotPower']]
# Out:
#             Name         Club    Wage  Age  ShotPower
# 291      Mariano  Real Madrid  140000   24         85
# 6279  L. Quezada   Córdoba CF    2000   22         66

# %%
# Задание 6.7
#Посчитайте среднюю зарплату (Wage) и цену (Value) игроков разных позиций (Position). 
#Представители какой позиции имеют самую высокую среднюю ценность?

df.groupby(['Position'])[['Value','Wage']].mean().sort_values(['Value'],ascending=False).head()
# Out:
#                  Value           Wage
# Position
# LF        2.736250e+07   75125.000000
# RF        2.636583e+07  119000.000000
# LAM       1.324583e+07   61000.000000
# RAM       8.345000e+06   11800.000000
# LS        5.848430e+06   15421.487603

# %%
#Функция nunique, которая позволяет посчитать количество уникальных значений по серии. 
#Её лучше всего применять к тем колонкам датафрейма,
#в которых хранятся категорийные данные:
df.groupby(['Nationality'])[['Club','Name']].nunique()
# Out:
#              Club  Name
# Nationality
# Afghanistan     4     4
# Albania        26    29
# Algeria        33    37
# Andorra         1     1
# Angola          9    10
# ...           ...   ...
# Uzbekistan      2     2
# Venezuela      34    36
# Wales          56   101
# Zambia          5     6
# Zimbabwe        8     9
#
# [156 rows x 2 columns]

# %%
#ункция count, с помощью которой можно посчитать количество элементов в группе. 
#То есть результат её будет такой же, как у функции value_counts, которую мы изучали в предыдущем уроке.
df.groupby(['Club'])['Name'].count()
# Out:
# Club
#  SSV Jahn Regensburg     24
# 1. FC Heidenheim 1846    20
# 1. FC Kaiserslautern     23
# 1. FC Köln               10
# 1. FC Magdeburg          21
#                          ..
# Zagłębie Sosnowiec       25
# Çaykur Rizespor          22
# Örebro SK                26
# Östersunds FK            20
# Śląsk Wrocław            24
# Name: Name, Length: 650, dtype: int64

# %%
#Функция median, с помощью которой можно посчитать медианное значение:
df.groupby(['Club'])['Dribbling'].median()
# Out:
# Club
#  SSV Jahn Regensburg     57.5
# 1. FC Heidenheim 1846    59.5
# 1. FC Kaiserslautern     54.0
# 1. FC Köln               60.5
# 1. FC Magdeburg          53.0
#                          ...
# Zagłębie Sosnowiec       58.0
# Çaykur Rizespor          62.0
# Örebro SK                55.0
# Östersunds FK            61.5
# Śląsk Wrocław            54.5
# Name: Dribbling, Length: 650, dtype: float64

# %%
#Функция min, с помощью которой можно посчитать минимальное значение внутри группы:
df.groupby(['Club'])['Balance'].min()
# Out:
# Club
#  SSV Jahn Regensburg     29
# 1. FC Heidenheim 1846    22
# 1. FC Kaiserslautern     29
# 1. FC Köln               31
# 1. FC Magdeburg          19
#                          ..
# Zagłębie Sosnowiec       28
# Çaykur Rizespor          39
# Örebro SK                34
# Östersunds FK            32
# Śląsk Wrocław            31
# Name: Balance, Length: 650, dtype: int64

# %%
#6.9.1
#Посчитайте среднюю (mean) и медианную (median) зарплату (Wage) футболистов из разных клубов (Club). 
#В скольких клубах средняя и медианная зарплаты совпадают?
#Подсказка: чтобы в процессе группировки применить к данным одновременно две агрегирующие функции, 
#необходимо указать их как аргументы метода agg:
#df.groupby(столбец_для_группировки)[столбцы_для_отображения].agg(['функция_1', 'функция_2'])
df.groupby('Club')['Wage'].agg(['mean', 'median']).count('mean'=='median')

ft_gr = football.groupby(['Club'])['Wage'].agg(['mean', 'median'])
len(ft_gr[ft_gr['mean']==ft_gr['median']])
# Out:
# 52

# %%
#Продолжаем работать с клубами, в которых средняя зарплата совпадает с медианной. 
#Каков максимальный размер средней зарплаты в этой группе клубов?
display (ft_gr[ft_gr['mean']==ft_gr['median']].max())

display (ft_gr[ft_gr['mean']==ft_gr['median']])
# Out:
# mean      13000.0
# median    13000.0
# dtype: float64
#                            mean  median
# Club
# 1. FC Magdeburg          4000.0    4000
# AEK Athens               1000.0    1000
# AJ Auxerre               2000.0    2000
# Benevento                2000.0    2000
# Bohemian FC              1000.0    1000
# Boyacá Chicó FC          1000.0    1000
# Bray Wanderers           1000.0    1000
# Brøndby IF               6000.0    6000
# CD Feirense              4000.0    4000
# CD Tondela               2000.0    2000
# Cork City                1000.0    1000
# Cruzeiro                13000.0   13000
# Deportivo Pasto          1000.0    1000
# Dinamo Zagreb            1000.0    1000
# Dundalk                  1000.0    1000
# Dynamo Kyiv              1000.0    1000
# Envigado FC              1000.0    1000
# FC Energie Cottbus       1000.0    1000
# FC Metz                  1500.0    1500
# Grimsby Town             2000.0    2000
# Göztepe SK               7000.0    7000
# ...

# %%
#С помощью функции groupby посчитайте сумму зарплат (Wage) футболистов клуба (Club) "Chelsea".
grouped_df = df.groupby(['Club']).sum()

grouped_df.loc['Chelsea']
grouped_df.loc['Chelsea']['Wage']
# Out:
# 2035000

# %%
#Определите максимальную зарплату футболиста 
#национальности (Nationality) Аргентина ("Argentina") в возрасте 20 лет.


df = pd.read_csv('data_sf.csv')

df[(df.Nationality == 'Argentina')&(df.Age == 20)].Wage.max()
# Out:
# 54000

# %%
#Определите максимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") в возрасте 30 лет.
df[(df.Nationality == 'Argentina')&(df.Age == 30)].Wage.max()
# Out:
# 300000

# %%
#Определите минимальную зарплату футболиста национальности (Nationality) Аргентина ("Argentina") в возрасте 30 лет.
df[(df.Nationality == 'Argentina')&(df.Age == 30)].Wage.min()
# Out:
# 1000

# %%
#Определите максимальную силу (Strength) и баланс (Balance)#
#среди игроков клуба (Club) "FC Barcelona" из Аргентины ("Argentina"). 
#Ответ введите через точку с запятой без пробела.
a = df[(df.Nationality == 'Argentina')&(df.Club == 'FC Barcelona')].Strength.max();
b = df[(df.Nationality == 'Argentina')&(df.Club == 'FC Barcelona')].Balance.max()
print(a)
print(b)
# Out:
# 59
# 95

# %%
'''Для начала разберем конструкцию df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])]. Она позволяет отфильтровать датафрейм по колонке Club, где значение в колонке соответствует одному из перечисленных в массиве клубов.

Дальше посмотрим на параметры функции pivot_table:

            В параметр values мы передаем ту колонку, по которой нам нужно строить сводные данные, применяя агрегирующую функцию сумма.
            В параметр index передадим ту колонку, данные которой будут представлены строками сводной таблицы.
            В параметр columns передаем колонку, значения которой будут в столбцах.
            В параметр aggfunc передаем агрегирующую функцию. Помните, мы проходили их, когда рассматривали функцию groupby? Все эти функции можно применять и при построении сводных таблиц.
'''
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum')
display(pivot)
# Out:
#                            Wage
# Club               FC Barcelona  Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0  205000.0          206000.0         NaN
# Belgium                110000.0       NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN  180000.0               NaN         NaN
# Brazil                 465000.0  335000.0           91000.0    570000.0
# Chile                  205000.0       NaN          215000.0         NaN
# Costa Rica                  NaN       NaN               NaN    195000.0
# Croatia                260000.0  160000.0               NaN    420000.0
# Dominican Republic          NaN       NaN               NaN    140000.0
# Ecuador                     NaN       NaN          120000.0         NaN
# England                     NaN       NaN          478000.0         NaN
# France                 495000.0  145000.0          375000.0    459000.0
# ...

# %%
#Для того, чтобы добавить столбец и строку с итоговыми значениями, нужно добавить параметр margins=True:
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True)
display(pivot)
# Out:
#                            Wage                                           \
# Club               FC Barcelona   Juventus Manchester United Real Madrid
# Nationality
# Argentina              565000.0   205000.0          206000.0         NaN
# Belgium                110000.0        NaN          230000.0    240000.0
# Bosnia Herzegovina          NaN   180000.0               NaN         NaN
# Brazil                 465000.0   335000.0           91000.0    570000.0
# Chile                  205000.0        NaN          215000.0         NaN
# Costa Rica                  NaN        NaN               NaN    195000.0
# Croatia                260000.0   160000.0               NaN    420000.0
# Dominican Republic          NaN        NaN               NaN    140000.0
# Ecuador                     NaN        NaN          120000.0         NaN
# England                     NaN        NaN          478000.0         NaN
# France                 495000.0   145000.0          375000.0    459000.0
# ...

# %%
''' Задание 1
1 point possible (graded)

Сводная таблица, показывающая максимальные зарплаты игроков на разных позициях, играющих за разные клубы, была создана с помощью кода:

df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')

С помощью какого кода можно получить из этой таблицы информацию о максимальной зарплате вратаря (GK), играющего за футбольный клуб "Manchester City"?'''
df2 = df.pivot_table(columns = 'Position', index = 'Club', values = 'Wage', aggfunc = 'max')
df2.loc['Manchester City']['GK']
# Out:
# 125000.0

# %%
'''Замена отсутствующих значений

Обратите внимание, что в нашем датафрейме получилось много NaN (Not a Number). 
Это означает, что на пересечении строки и столбца нет данных, 
например, в клубе Juventus нет футболистов из Бельгии'''
pivot.loc['Belgium']
# Out:
#       Club
# Wage  FC Barcelona         110000.0
#       Juventus                  NaN
#       Manchester United    230000.0
#       Real Madrid          240000.0
# Name: Belgium, dtype: float64

# %%
'''Для того, чтобы заменить NaN на 0, можно применить дополнительный параметр fill_value. 
Этот параметр принимает значение, которым нужно заполнить все NaN в получившейся сводной таблице:'''
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Wage'],
index=['Nationality'],
columns=['Club'],
aggfunc='sum',
margins=True,
fill_value=0)
display(pivot)
# Out:
#                            Wage                                         \
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                565000   205000            206000           0
# Belgium                  110000        0            230000      240000
# Bosnia Herzegovina            0   180000                 0           0
# Brazil                   465000   335000             91000      570000
# Chile                    205000        0            215000           0
# Costa Rica                    0        0                 0      195000
# Croatia                  260000   160000                 0      420000
# Dominican Republic            0        0                 0      140000
# Ecuador                       0        0            120000           0
# England                       0        0            478000           0
# France                   495000   145000            375000      459000
# ...

# %%
'''Еще примеры сводных таблиц

Применим другую агрегирующую функцию count,
чтобы посчитать количество футболистов по клубам и национальностям:'''
pivot = df.loc[df['Club'].isin(['FC Barcelona','Real Madrid','Juventus','Manchester United'])].pivot_table(values=['Name'],
index=['Nationality'],
columns=['Club'],
aggfunc='count',
fill_value=0)
display(pivot)
# Out:
#                            Name
# Club               FC Barcelona Juventus Manchester United Real Madrid
# Nationality
# Argentina                     1        1                 2           0
# Belgium                       1        0                 1           1
# Bosnia Herzegovina            0        1                 0           0
# Brazil                        2        2                 1           2
# Chile                         1        0                 1           0
# Costa Rica                    0        0                 0           1
# Croatia                       1        1                 0           1
# Dominican Republic            0        0                 0           1
# Ecuador                       0        0                 1           0
# England                       0        0                 6           0
# France                        3        1                 2           3
# Germany                       1        1                 0           1
# ...

# %%
'''Создайте сводную таблицу, содержащую сведения о количестве игроков, занимающих разные позиции в каждом клубе. 
Отсутствующие значения замените нулями.

Каково среднее количество вратарей (GK) в клубе? Ответ округлите до трёх цифр после запятой.'''
pivotGK= df.pivot_table(values='Name',
        index='Club',
        columns='Position',
        aggfunc='nunique',
        fill_value=0)
round(pivotGK.GK.mean(),3)
# Out:
# 2.525

# %%
'''Используя таблицу, созданную на предыдущем шаге, определите, 
сколько клубов не содержат данных о центральных полузащитниках. (CM)
Подсказка: для выполнения этого задания желательно сохранить
сводную таблицу в виде отдельного датафрейма и сгруппировать часть данных этого 
датафрейма с помощью value_counts().'''

pivot = football.pivot_table(values='Name',
index='Position',
columns='Club',
aggfunc='count',
fill_value=0,
margins=True)
new_1 = pivot.loc['CM'].value_counts()
display(new_1)

# 136
# Out:
# 1       211
# 2       149
# 0       136
# 3        89
# 4        39
# 5        21
# 6         5
# 1067      1
# Name: CM, dtype: int64

# %%
pivotCM= df.loc[df['Position'].isin(['CM'])].pivot_table(values ='Name',
        index='Club',
        columns='Position',
        aggfunc='nunique',
        fill_value=0)


ZERO_CM = df[df.Position == 0].value_counts()
display(pivotCM)
# Out:
# Position               CM
# Club
#  SSV Jahn Regensburg    2
# 1. FC Heidenheim 1846   1
# 1. FC Köln              2
# 1. FC Nürnberg          1
# 1. FC Union Berlin      1
# ...                    ..
# Yokohama F. Marinos     1
# Zagłębie Lubin          1
# Örebro SK               1
# Östersunds FK           3
# Śląsk Wrocław           1
#
# [514 rows x 1 columns]

# %%
#Добрый день, задачу 6.14.3
#Используя таблицу, созданную на предыдущем шаге, отметьте названия трёх клубов, 
#в которых центральные форварды (ST) обладают наибольшей средней скоростью.
pivot = df.pivot_table(values = 'SprintSpeed', columns = 'Position', index = 'Club', aggfunc = 'mean', fill_value = 0)
pivot['ST'].sort_values(ascending=False).head(3)
# Out:
# Club
# Vitória      91.0
# Sydney FC    88.0
# CD Lugo      87.0
# Name: ST, dtype: float64

# %%
#С помощью сводной таблицы и функции loc посчитайте, 
#сколько получают ("Wage") русские футболисты ("Russia"), играющие за ФК "AS Monaco".
df3 = df.pivot_table(columns = 'Nationality', index = 'Club', values = 'Wage', aggfunc = 'sum')

df3.loc['AS Monaco']['Russia']
# Out:
# 61000.0

# %%
'''Создайте сводную таблицу, содержащую сведения о средней скорости футболистов 
(SprintSpeed), занимающих разные позиции (Position) в разных футбольных клубах (Club).
Основываясь на данных таблицы, отметьте три позиции, представители которых в 
среднем обладают самой высокой скоростью.'''

f  = df.pivot_table(columns = 'Position',
                    index = 'Club',
                    values = 'SprintSpeed',
                    aggfunc = 'mean',
                    fill_value=0)
f.max().sort_values( ascending=False )
# Out:
# Position
# RS     94.0
# RM     94.0
# LM     94.0
# LS     93.0
# RB     93.0
# LB     93.0
# CF     91.0
# LW     91.0
# ST     91.0
# RDM    91.0
# RW     91.0
# RCM    90.0
# CAM    89.0
# LF     88.0
# RCB    88.0
# LCB    88.0
# RWB    86.0
# RF     86.0
# CM     86.0
# LWB    86.0
# LAM    85.0
# LCM    84.0
# CDM    83.0
# LDM    79.0
# RAM    78.0
# CB     78.0
# GK     62.0
# dtype: float64
